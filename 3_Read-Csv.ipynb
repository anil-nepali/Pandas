# %%
import pandas as pd

df = pd.read_csv('data.csv')

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# CSV stands for Comma Separated Values. 
# It's a simple text file where data is stored in rows and columns,
# separated by commas, like a table in Excel or a database.

# To read data from various file formats using Pandas:

# 1. **Read a CSV file**
# This reads the CSV file named 'data.csv' and stores it in a DataFrame called 'df'
'''df = pd.read_csv("data.csv")

# 2. **Read an Excel file**
# This reads the Excel file named 'data.xlsx' and stores it in a DataFrame called 'df'
df = pd.read_excel("data.xlsx")

# 3. **Read a JSON file**
# This reads the JSON file named 'data.json' and stores it in a DataFrame called 'df'
df = pd.read_json("data.json")

# To display the DataFrame:

# 4. **Print the entire DataFrame** 
# This prints the entire DataFrame (be careful with large data)
print(df.to_string())

# 5. **Print the first 5 rows**
# This prints the first 5 rows and columns, which is safer for large datasets
print(df.head())'''

# Notes:
# - 'head()' is better for exploring large datasets without printing everything at once.
# - Use 'to_string()' to view the entire DataFrame (not recommended for very large files).
# Out:
# 'df = pd.read_csv("data.csv")\n\n# 2. **Read an Excel file**\n# This reads the Excel file named \'data.xlsx\' and stores it in a DataFrame called \'df\'\ndf = pd.read_excel("data.xlsx")\n\n# 3. **Read a JSON file**\n# This reads the JSON file named \'data.json\' and stores it in a DataFrame called \'df\'\ndf = pd.read_json("data.json")\n\n# To display the DataFrame:\n\n# 4. **Print the entire DataFrame** \n# This prints the entire DataFrame (be careful with large data)\nprint(df.to_string())\n\n# 5. **Print the first 5 rows**\n# This prints the first 5 rows and columns, which is safer for large datasets\nprint(df.head())'

# %%
import pandas as pd
df=pd.read_csv("sales_data_sample.csv",encoding="latin1")
print(df)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
import pandas as pd

df = pd.read_csv("sales_data_sample.csv", encoding='latin1')  # or 'ISO-8859-1', or 'cp1252'
print(df.head())
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
import pandas as pd

df = pd.read_excel("SampleSuperstore.xlsx",engine="xlrd")
print(df.head())
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
print(df.shape)
print(df.size)
# Out:
# (9994, 21)
# 209874

# %%
import pandas as pd
df=pd.read_json("sample_Data.json")
print(df.head())
# Out:
#    id                                         name  \
# 0   1                              Apple iPhone 12
# 1   2                           Samsung Galaxy S21
# 2   3                           Sony PlayStation 5
# 3   4            LG OLED55CXPUA 55-inch 4K OLED TV
# 4   5  Bose QuietComfort 35 II Wireless Headphones
#
#                                          description    price     category  \
# 0  The Apple iPhone 12 features a 6.1-inch Super ...   999.00  Electronics
# 1  The Samsung Galaxy S21 features a 6.2-inch Dyn...   799.00  Electronics
# 2  The Sony PlayStation 5 features an AMD Zen 2-b...   499.99  Electronics
# 3  The LG OLED55CXPUA 55-inch 4K OLED TV features...  1599.99  Electronics
# 4  The Bose QuietComfort 35 II Wireless Headphone...   299.00  Electronics
#
#                                                image
# 0  https://www.apple.com/newsroom/images/product/...
# 1  https://images.samsung.com/is/image/samsung/p6...
# ...
